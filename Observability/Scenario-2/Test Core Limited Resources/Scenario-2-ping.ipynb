# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
df_low_core_cpu_usage = pd.read_csv('csv/low/core-cpu-usage.csv',  delimiter=',', header=0)
df_low_core_cpu_usage['Time'] = pd.to_datetime(df_low_core_cpu_usage['Time'])
df_low_core_cpu_usage["free5gc"] = pd.to_numeric(df_low_core_cpu_usage['free5gc'])

df_high_core_cpu_usage = pd.read_csv('csv/high/core-cpu-usage.csv',  delimiter=',', header=0)
df_high_core_cpu_usage['Time'] = pd.to_datetime(df_high_core_cpu_usage['Time'])
df_high_core_cpu_usage["free5gc"] = pd.to_numeric(df_high_core_cpu_usage['free5gc'])

# %%
df_low_cu_cpu_usage = pd.read_csv('csv/low/cu-cpu-usage.csv',  delimiter=',', header=0)
df_low_cu_cpu_usage['Time'] = pd.to_datetime(df_low_cu_cpu_usage['Time'])
df_low_cu_cpu_usage["cu"] = pd.to_numeric(df_low_cu_cpu_usage['cu'])

df_high_cu_cpu_usage = pd.read_csv('csv/high/cu-cpu-usage.csv',  delimiter=',', header=0)
df_high_cu_cpu_usage['Time'] = pd.to_datetime(df_high_cu_cpu_usage['Time'])
df_high_cu_cpu_usage["cu"] = pd.to_numeric(df_high_cu_cpu_usage['cu'])

# %%
df_low_du_cpu_usage = pd.read_csv('csv/low/du-cpu-usage.csv',  delimiter=',', header=0)
df_low_du_cpu_usage['Time'] = pd.to_datetime(df_low_du_cpu_usage['Time'])
df_low_du_cpu_usage["du"] = pd.to_numeric(df_low_du_cpu_usage['du'])

df_high_du_cpu_usage = pd.read_csv('csv/high/du-cpu-usage.csv',  delimiter=',', header=0)
df_high_du_cpu_usage['Time'] = pd.to_datetime(df_high_du_cpu_usage['Time'])
df_high_du_cpu_usage["du"] = pd.to_numeric(df_high_du_cpu_usage['du'])

# %%
df_low_ru_cpu_usage = pd.read_csv('csv/low/ru-cpu-usage.csv',  delimiter=',', header=0)
df_low_ru_cpu_usage['Time'] = pd.to_datetime(df_low_ru_cpu_usage['Time'])
df_low_ru_cpu_usage["ru"] = pd.to_numeric(df_low_ru_cpu_usage['ru'])

df_high_ru_cpu_usage = pd.read_csv('csv/high/ru-cpu-usage.csv',  delimiter=',', header=0)
df_high_ru_cpu_usage['Time'] = pd.to_datetime(df_high_ru_cpu_usage['Time'])
df_high_ru_cpu_usage["ru"] = pd.to_numeric(df_high_ru_cpu_usage['ru'])

# %%
df_low_ran_limits_cpu_usage = pd.read_csv('csv/low/limits-cu-cpu-usage.csv',  delimiter=',', header=0)
df_low_ran_limits_cpu_usage['Time'] = pd.to_datetime(df_low_ran_limits_cpu_usage['Time'])
df_low_ran_limits_cpu_usage["limits"] = pd.to_numeric(df_low_ran_limits_cpu_usage['limits'])

df_high_ran_limits_cpu_usage = pd.read_csv('csv/high/limits-cu-cpu-usage.csv',  delimiter=',', header=0)
df_high_ran_limits_cpu_usage['Time'] = pd.to_datetime(df_high_ran_limits_cpu_usage['Time'])
df_high_ran_limits_cpu_usage["limits"] = pd.to_numeric(df_high_ran_limits_cpu_usage['limits'])

# %%
df_low_core_limits_cpu_usage = pd.read_csv('csv/low/limits-core-cpu-usage.csv',  delimiter=',', header=0)
df_low_core_limits_cpu_usage['Time'] = pd.to_datetime(df_low_core_limits_cpu_usage['Time'])
df_low_core_limits_cpu_usage["limits"] = pd.to_numeric(df_low_core_limits_cpu_usage['limits'])

df_high_core_limits_cpu_usage = pd.read_csv('csv/high/limits-core-cpu-usage.csv',  delimiter=',', header=0)
df_high_core_limits_cpu_usage['Time'] = pd.to_datetime(df_high_core_limits_cpu_usage['Time'])
df_high_core_limits_cpu_usage["limits"] = pd.to_numeric(df_high_core_limits_cpu_usage['limits'])

# %%
df_low_core_mem_usage = pd.read_csv('csv/low/core-mem-usage.csv',  delimiter=',', header=0)
df_low_core_mem_usage['Time'] = pd.to_datetime(df_low_core_mem_usage['Time'])
df_low_core_mem_usage["free5gc"] = pd.to_numeric(df_low_core_mem_usage["free5gc"])
df_low_core_mem_usage['free5gc']= df_low_core_mem_usage["free5gc"] / 1024 /1024


df_high_core_mem_usage = pd.read_csv('csv/high/core-mem-usage.csv',  delimiter=',', header=0)
df_high_core_mem_usage['Time'] = pd.to_datetime(df_high_core_mem_usage['Time'])
df_high_core_mem_usage["free5gc"] = pd.to_numeric(df_high_core_mem_usage["free5gc"])
df_high_core_mem_usage['free5gc']= df_high_core_mem_usage["free5gc"] / 1024 / 1024

# %%
df_low_cu_mem_usage = pd.read_csv('csv/low/cu-mem-usage.csv',  delimiter=',', header=0)
df_low_cu_mem_usage['Time'] = pd.to_datetime(df_low_cu_mem_usage['Time'])
df_low_cu_mem_usage["cu"] = pd.to_numeric(df_low_cu_mem_usage["cu"])
df_low_cu_mem_usage["cu"] = df_low_cu_mem_usage["cu"] / 1024 / 1024

df_high_cu_mem_usage = pd.read_csv('csv/high/cu-mem-usage.csv',  delimiter=',', header=0)
df_high_cu_mem_usage['Time'] = pd.to_datetime(df_high_cu_mem_usage['Time'])
df_high_cu_mem_usage["cu"] = pd.to_numeric(df_high_cu_mem_usage["cu"])
df_high_cu_mem_usage["cu"] = df_high_cu_mem_usage["cu"] / 1024 / 1024

# %%
df_low_du_mem_usage = pd.read_csv('csv/low/du-mem-usage.csv',  delimiter=',', header=0)
df_low_du_mem_usage['Time'] = pd.to_datetime(df_low_du_mem_usage['Time'])
df_low_du_mem_usage["du"] = pd.to_numeric(df_low_du_mem_usage["du"])
df_low_du_mem_usage["du"] = df_low_du_mem_usage["du"] / 1024 / 1024

df_high_du_mem_usage = pd.read_csv('csv/high/du-mem-usage.csv',  delimiter=',', header=0)
df_high_du_mem_usage['Time'] = pd.to_datetime(df_high_du_mem_usage['Time'])
df_high_du_mem_usage["du"] = pd.to_numeric(df_high_du_mem_usage["du"])
df_high_du_mem_usage["du"] = df_high_du_mem_usage["du"] / 1024 / 1024

# %%
df_low_ru_mem_usage = pd.read_csv('csv/low/ru-mem-usage.csv',  delimiter=',', header=0)
df_low_ru_mem_usage['Time'] = pd.to_datetime(df_low_ru_mem_usage['Time'])
df_low_ru_mem_usage["ru"] = pd.to_numeric(df_low_ru_mem_usage["ru"])
df_low_ru_mem_usage["ru"] = df_low_ru_mem_usage["ru"] / 1024 / 1024

df_high_ru_mem_usage = pd.read_csv('csv/high/ru-mem-usage.csv',  delimiter=',', header=0)
df_high_ru_mem_usage['Time'] = pd.to_datetime(df_high_ru_mem_usage['Time'])
df_high_ru_mem_usage["ru"] = pd.to_numeric(df_high_ru_mem_usage["ru"])
df_high_ru_mem_usage["ru"] = df_high_ru_mem_usage["ru"] / 1024 / 1024

# %%
df_low_ran_limits_mem_usage = pd.read_csv('csv/low/limits-cu-mem-usage.csv',  delimiter=',', header=0)
df_low_ran_limits_mem_usage['Time'] = pd.to_datetime(df_low_ran_limits_mem_usage['Time'])
df_low_ran_limits_mem_usage["limits"] = pd.to_numeric(df_low_ran_limits_mem_usage["limits"])
df_low_ran_limits_mem_usage["limits"] = df_low_ran_limits_mem_usage["limits"] / 1024 / 1024

df_high_ran_limits_mem_usage = pd.read_csv('csv/high/limits-cu-mem-usage.csv',  delimiter=',', header=0)
df_high_ran_limits_mem_usage['Time'] = pd.to_datetime(df_high_ran_limits_mem_usage['Time'])
df_high_ran_limits_mem_usage["limits"] = pd.to_numeric(df_high_ran_limits_mem_usage["limits"])
df_high_ran_limits_mem_usage["limits"] = df_high_ran_limits_mem_usage["limits"] / 1024 / 1024

# %%
df_low_core_limits_mem_usage = pd.read_csv('csv/low/limits-core-mem-usage.csv',  delimiter=',', header=0)
df_low_core_limits_mem_usage['Time'] = pd.to_datetime(df_low_core_limits_mem_usage['Time'])
df_low_core_limits_mem_usage["limits"] = pd.to_numeric(df_low_core_limits_mem_usage["limits"])
df_low_core_limits_mem_usage["limits"] = df_low_core_limits_mem_usage["limits"] / 1024 / 1024

df_high_core_limits_mem_usage = pd.read_csv('csv/high/limits-core-mem-usage.csv',  delimiter=',', header=0)
df_high_core_limits_mem_usage['Time'] = pd.to_datetime(df_high_core_limits_mem_usage['Time'])
df_high_core_limits_mem_usage["limits"] = pd.to_numeric(df_high_core_limits_mem_usage["limits"])
df_high_core_limits_mem_usage["limits"] = df_high_core_limits_mem_usage["limits"] / 1024 / 1024

# %%
df_low_logs = pd.read_csv('csv/low/logs.csv',  delimiter='::', header=0, engine='python')
df_low_logs['time'] = pd.to_datetime(df_low_logs['time'])
df_low_logs_count = df_low_logs.groupby(['time','kubernetes.container_name']).size().reset_index(name='counts')
df_low_logs_count_core = df_low_logs_count.loc[df_low_logs_count['kubernetes.container_name'] == 'free5gc']
df_low_logs_count_cu = df_low_logs_count.loc[df_low_logs_count['kubernetes.container_name'] == 'cu']
df_low_logs_count_du = df_low_logs_count.loc[df_low_logs_count['kubernetes.container_name'] == 'du']
df_low_logs_count_ru = df_low_logs_count.loc[df_low_logs_count['kubernetes.container_name'] == 'ru']

df_high_logs = pd.read_csv('csv/high/logs.csv',  delimiter='::', header=0, engine='python')
df_high_logs['time'] = pd.to_datetime(df_high_logs['time'])
df_high_logs_count = df_high_logs.groupby(['time','kubernetes.container_name']).size().reset_index(name='counts')
df_high_logs_count_core = df_high_logs_count.loc[df_high_logs_count['kubernetes.container_name'] == 'free5gc']
df_high_logs_count_cu = df_high_logs_count.loc[df_high_logs_count['kubernetes.container_name'] == 'cu']
df_high_logs_count_du = df_high_logs_count.loc[df_high_logs_count['kubernetes.container_name'] == 'du']
df_high_logs_count_ru = df_high_logs_count.loc[df_high_logs_count['kubernetes.container_name'] == 'ru']

# %%
all_seconds_low = pd.date_range('2022-01-27 14:30:00', '2022-01-27 14:37:00', freq='s')
all_seconds_high = pd.date_range('2022-01-27 14:22:00', '2022-01-27 14:29:00', freq='s')

df_low_logs_count_cu.index = pd.DatetimeIndex(df_low_logs_count_cu['time'])
df_low_logs_count_cu = df_low_logs_count_cu.reindex(all_seconds_low)
df_low_logs_count_cu['kubernetes.container_name'] = df_low_logs_count_cu['kubernetes.container_name'].fillna('cu')
df_low_logs_count_cu['counts'] = df_low_logs_count_cu['counts'].fillna(0)

df_high_logs_count_cu.index = pd.DatetimeIndex(df_high_logs_count_cu['time'])
df_high_logs_count_cu = df_high_logs_count_cu.reindex(all_seconds_high)
df_high_logs_count_cu['kubernetes.container_name'] = df_high_logs_count_cu['kubernetes.container_name'].fillna('cu')
df_high_logs_count_cu['counts'] = df_high_logs_count_cu['counts'].fillna(0)

df_low_logs_count_du.index = pd.DatetimeIndex(df_low_logs_count_du['time'])
df_low_logs_count_du = df_low_logs_count_du.reindex(all_seconds_low)
df_low_logs_count_du['kubernetes.container_name'] = df_low_logs_count_du['kubernetes.container_name'].fillna('du')
df_low_logs_count_du['counts'] = df_low_logs_count_du['counts'].fillna(0)

df_high_logs_count_du.index = pd.DatetimeIndex(df_high_logs_count_du['time'])
df_high_logs_count_du = df_high_logs_count_du.reindex(all_seconds_high)
df_high_logs_count_du['kubernetes.container_name'] = df_high_logs_count_du['kubernetes.container_name'].fillna('du')
df_high_logs_count_du['counts'] = df_high_logs_count_du['counts'].fillna(0)

df_low_logs_count_ru.index = pd.DatetimeIndex(df_low_logs_count_ru['time'])
df_low_logs_count_ru = df_low_logs_count_ru.reindex(all_seconds_low)
df_low_logs_count_ru['kubernetes.container_name'] = df_low_logs_count_ru['kubernetes.container_name'].fillna('ru')
df_low_logs_count_ru['counts'] = df_low_logs_count_ru['counts'].fillna(0)

df_high_logs_count_ru.index = pd.DatetimeIndex(df_high_logs_count_ru['time'])
df_high_logs_count_ru = df_high_logs_count_ru.reindex(all_seconds_high)
df_high_logs_count_ru['kubernetes.container_name'] = df_high_logs_count_ru['kubernetes.container_name'].fillna('ru')
df_high_logs_count_ru['counts'] = df_high_logs_count_ru['counts'].fillna(0)

df_low_logs_count_core.index = pd.DatetimeIndex(df_low_logs_count_core['time'])
df_low_logs_count_core = df_low_logs_count_core.reindex(all_seconds_low)
df_low_logs_count_core['kubernetes.container_name'] = df_low_logs_count_core['kubernetes.container_name'].fillna('free5gc')
df_low_logs_count_core['counts'] = df_low_logs_count_core['counts'].fillna(value=0)

df_high_logs_count_core.index = pd.DatetimeIndex(df_high_logs_count_core['time'])
df_high_logs_count_core = df_high_logs_count_core.reindex(all_seconds_high)
df_high_logs_count_core['kubernetes.container_name'] = df_high_logs_count_core['kubernetes.container_name'].fillna('free5gc')
df_high_logs_count_core['counts'] = df_high_logs_count_core['counts'].fillna(value=0)

# %%
df_low_logs_count_sum = pd.DataFrame()
df_low_logs_count_sum = df_low_logs_count_sum.reindex(all_seconds_low)
df_low_logs_count_sum['ru'] = df_low_logs_count_ru['counts']
df_low_logs_count_sum['ru-du'] = df_low_logs_count_ru['counts'] + df_low_logs_count_du['counts']
df_low_logs_count_sum['ru-du-cu'] = df_low_logs_count_ru['counts'] + df_low_logs_count_du['counts'] + df_low_logs_count_cu['counts']

df_high_logs_count_sum = pd.DataFrame()
df_high_logs_count_sum = df_high_logs_count_sum.reindex(all_seconds_high)
df_high_logs_count_sum['ru'] = df_high_logs_count_ru['counts']
df_high_logs_count_sum['ru-du'] = df_high_logs_count_ru['counts'] + df_high_logs_count_du['counts']
df_high_logs_count_sum['ru-du-cu'] = df_high_logs_count_ru['counts'] + df_high_logs_count_du['counts'] + df_high_logs_count_cu['counts']

# %%
df_low_ping = pd.read_csv('csv/low/ping.csv',  delimiter=';', header=0)
df_low_ping['time'] = pd.to_datetime(df_low_ping['time'])
df_low_ping["Latency(ms)"] = pd.to_numeric(df_low_ping["Latency(ms)"])

df_high_ping = pd.read_csv('csv/high/ping.csv',  delimiter=';', header=0)
df_high_ping['time'] = pd.to_datetime(df_high_ping['time'])
df_high_ping["Latency(ms)"] = pd.to_numeric(df_high_ping["Latency(ms)"])

# %%
sns.set_context('paper', font_scale=1.5)
fig, axes = plt.subplots(nrows=5, ncols=2, sharex='col', figsize=(15,10))
axes[0,0].set_xlabel('Time')
axes[0,1].set_xlabel('Time')

df_low_core_cpu_usage.plot(kind='line', y='free5gc', x='Time',label='Core', ax=axes[0,0], color='tab:blue')
df_low_cu_cpu_usage.plot(kind='line', y='cu', x='Time',label='CU', ax=axes[0,0], color='tab:orange')
df_low_du_cpu_usage.plot(kind='line', y='du', x='Time',label='DU', ax=axes[0,0], color='tab:green')
df_low_ru_cpu_usage.plot(kind='line', y='ru', x='Time',label='RU', ax=axes[0,0], color='tab:red')
df_low_ran_limits_cpu_usage.plot(kind='line', y='limits', x='Time',label='RAN Lim.', linewidth=2, linestyle='dotted', ax=axes[0,0])
df_low_core_limits_cpu_usage.plot(kind='line', y='limits', x='Time',label='Core Lim.', linewidth=2, linestyle='dashed', ax=axes[0,0])
axes[0,0].set_ylabel('CPU(Millicpu)')

df_high_core_cpu_usage.plot(kind='line', y='free5gc', x='Time',label='Core', ax=axes[0,1], color='tab:blue')
df_high_cu_cpu_usage.plot(kind='line', y='cu', x='Time',label='CU', ax=axes[0,1], color='tab:orange')
df_high_du_cpu_usage.plot(kind='line', y='du', x='Time',label='DU', ax=axes[0,1], color='tab:green')
df_high_ru_cpu_usage.plot(kind='line', y='ru', x='Time',label='RU', ax=axes[0,1], color='tab:red')
df_high_ran_limits_cpu_usage.plot(kind='line', y='limits', x='Time',label='RAN Lim.', linewidth=2, linestyle='dotted', ax=axes[0,1])
df_high_core_limits_cpu_usage.plot(kind='line', y='limits', x='Time',label='Core Lim.', linewidth=2, linestyle='dashed', ax=axes[0,1])
axes[0,1].set_ylabel('CPU(Millicpu)')

df_low_core_mem_usage.plot(kind='line', y='free5gc', x='Time',label='Core', ax=axes[1,0], color='tab:blue')
df_low_cu_mem_usage.plot(kind='line', y='cu', x='Time',label='CU', ax=axes[1,0], color='tab:orange')
df_low_du_mem_usage.plot(kind='line', y='du', x='Time',label='DU', ax=axes[1,0], color='tab:green')
df_low_ru_mem_usage.plot(kind='line', y='ru', x='Time',label='RU', ax=axes[1,0], color='tab:red')
df_low_ran_limits_mem_usage.plot(kind='line', y='limits', x='Time',label='RAN Lim.',linewidth=2, linestyle='dotted', ax=axes[1,0])
df_low_core_limits_mem_usage.plot(kind='line', y='limits', x='Time',label='Core Lim.',linewidth=2, linestyle='dashed', ax=axes[1,0])
axes[1,0].set_ylabel('Memory(MiB)')

df_high_core_mem_usage.plot(kind='line', y='free5gc', x='Time',label='Core', ax=axes[1,1], color='tab:blue')
df_high_cu_mem_usage.plot(kind='line', y='cu', x='Time',label='CU', ax=axes[1,1], color='tab:orange')
df_high_du_mem_usage.plot(kind='line', y='du', x='Time',label='DU', ax=axes[1,1], color='tab:green')
df_high_ru_mem_usage.plot(kind='line', y='ru', x='Time',label='RU', ax=axes[1,1], color='tab:red')
df_high_ran_limits_mem_usage.plot(kind='line', y='limits', x='Time',label='RAN Lim.',linewidth=2, linestyle='dotted', ax=axes[1,1])
df_high_core_limits_mem_usage.plot(kind='line', y='limits', x='Time',label='Core Lim.',linewidth=2, linestyle='dashed', ax=axes[1,1])
axes[1,1].set_ylabel('Memory(MiB)')

df_low_ping.plot(kind='line',x='time',y='Latency(ms)', label='Latency' , ax=axes[2,0])
axes[2,0].axhline(y=df_low_ping['Latency(ms)'].mean(), linestyle='dotted')
axes[2,0].set_ylabel('ms')

df_high_ping.plot(kind='line',x='time',y='Latency(ms)', label='Latency' , ax=axes[2,1])
axes[2,1].axhline(y=df_high_ping['Latency(ms)'].mean(), linestyle='dotted')
axes[2,1].set_ylabel('ms')

df_low_logs_count_core.plot(kind='line',y='counts',label='Core', ax=axes[3,0], color='tab:blue')
#axes[3,0].fill_between(df_low_logs_count_core.index, 0, df_low_logs_count_core['counts'], alpha=0.5)
axes[3,0].set_ylabel('Logs/s')
axes[3,0].set_yscale('log')

df_high_logs_count_core.plot(kind='line',y='counts',label='Core', ax=axes[3,1], color='tab:blue')
#axes[3,1].fill_between(df_high_logs_count_core.index, 0, df_high_logs_count_core['counts'], alpha=0.5)
axes[3,1].set_ylabel('Logs/s')
axes[3,1].set_yscale('log')

df_low_logs_count_cu.plot(kind='line', y='counts', label='CU', ax=axes[4,0], color='tab:orange')
#axes[4,0].fill_between(df_low_logs_count_sum.index, 0, df_low_logs_count_sum['ru'], alpha=0.5)
df_low_logs_count_du.plot(kind='line', y='counts', label='DU', ax=axes[4,0], color='tab:green')
#axes[4,0].fill_between(df_low_logs_count_sum.index, df_low_logs_count_sum['ru'],df_low_logs_count_sum['ru-du'], alpha=0.5)
df_low_logs_count_ru.plot(kind='line', y='counts', label='RU', ax=axes[4,0], color='tab:red')
#axes[4,0].fill_between(df_low_logs_count_sum.index, df_low_logs_count_sum['ru-du'],df_low_logs_count_sum['ru-du-cu'],alpha=0.5)
axes[4,0].set_ylabel('Logs/s')
axes[4,0].set_yscale('log')

df_high_logs_count_cu.plot(kind='line', y='counts', label='CU', ax=axes[4,1], color='tab:orange')
#axes[4,1].fill_between(df_high_logs_count_sum.index, 0, df_high_logs_count_sum['ru'], alpha=0.5)
df_high_logs_count_du.plot(kind='line', y='counts', label='DU', ax=axes[4,1], color='tab:green')
#axes[4,1].fill_between(df_high_logs_count_sum.index, df_high_logs_count_sum['ru'],df_high_logs_count_sum['ru-du'], alpha=0.5)
df_high_logs_count_ru.plot(kind='line', y='counts', label='RU', ax=axes[4,1], color='tab:red')
#axes[4,1].fill_between(df_high_logs_count_sum.index, df_high_logs_count_sum['ru-du'],df_high_logs_count_sum['ru-du-cu'],alpha=0.5)
axes[4,1].set_ylabel('Logs/s')
axes[4,1].set_yscale('log')

for ax in axes:
    for each in ax:
        each.legend(labelspacing = 0.1, fontsize='12')

        each.axvline('2022/01/27 14:34:42',linestyle ="dotted", color='tab:gray')
        each.axvline('2022/01/27 14:35:41',linestyle ="dotted", color='tab:gray')
        each.axvline('2022/01/27 14:33:56',linestyle ="dotted", color='tab:gray')

        each.axvline('2022/01/27 14:27:01',linestyle ="dotted", color='tab:gray')
        each.axvline('2022/01/27 14:28:00',linestyle ="dotted", color='tab:gray')
        each.axvline('2022-01-27 14:26:15',linestyle ="dotted", color='tab:gray')

axes[0,0].set_title('(a) Underprovisioning')
axes[0,0].annotate('RAN Online', xy=('2022/01/27 14:33:56',0.4), xytext=(-15, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="right")
axes[0,0].annotate('Ping started', xy=('2022/01/27 14:34:42',0.4), xytext=(0, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="center")
axes[0,0].annotate('Ping stopped', xy=('2022/01/27 14:35:41',0.4), xytext=(15, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="left")
axes[2,0].annotate('Average latency = ' + str('{0:.3g}'.format(df_low_ping['Latency(ms)'].mean())), xy=('2022/01/27 14:32:00',df_low_ping['Latency(ms)'].mean()), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="center")

axes[0,1].set_title('(b) Overprovisioning')
axes[0,1].annotate('RAN Online', xy=('2022-01-27 14:26:15',0.4), xytext=(-15, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="right")
axes[0,1].annotate('Ping started', xy=('2022/01/27 14:27:01',0.4), xytext=(0, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="center")
axes[0,1].annotate('Ping stopped', xy=('2022/01/27 14:28:00',0.4), xytext=(15, -15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="left")
axes[2,1].annotate('Average latency = ' + str('{0:.3g}'.format(df_high_ping['Latency(ms)'].mean())), xy=('2022/01/27 14:24:00',df_high_ping['Latency(ms)'].mean()), xytext=(15, 15), textcoords='offset points', arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, horizontalalignment="center")

plt.savefig('out/out.pdf', dpi=300, bbox_inches='tight')
plt.savefig('out/out.png', dpi=300, bbox_inches='tight')
